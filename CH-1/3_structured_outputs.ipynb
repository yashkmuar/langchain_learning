# %% [markdown]
# # **Guiding in Prompts**

# %%
import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI

load_dotenv()

if os.environ.get("OPENAI_API_KEY"):
    print("Bro, you got the key, now move ahead")
else:
    print("Do some troubleshooting yrr!!")

llm_openai = ChatOpenAI(model="gpt-5-mini",temperature=0.4)
# Out:
# Bro, you got the key, now move ahead

# %%
from langchain_core.prompts import PromptTemplate

result = llm_openai.invoke("Tell me a joke. Generate the output in key-value pair with following keys: setup, punchline")

result.content
# Out:
# '{\n  "setup": "Why did the scarecrow win an award?",\n  "punchline": "Because he was outstanding in his field."\n}'

# %% [markdown]
# # ** Using Pydantic Models**
