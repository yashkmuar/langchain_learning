# %% [markdown]
# # **Guiding in Prompts**

# %%
import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI

load_dotenv()

if os.environ.get("OPENAI_API_KEY"):
    print("Bro, you got the key, now move ahead")
else:
    print("Do some troubleshooting yrr!!")

llm_openai = ChatOpenAI(model="gpt-5-mini",temperature=0.4)
# Out:
# Bro, you got the key, now move ahead

# %%
from langchain_core.prompts import PromptTemplate

llm_openai.invoke("Tell me a joke!!")
# Out:
# AIMessage(content='Sure — here are a few:\n\n1) Why don’t scientists trust atoms? Because they make up everything.\n\n2) Why did the programmer quit his job? He didn’t get arrays.\n\n3) I told my computer I needed a break — it replied, “Error 404: Coffee not found.”', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 262, 'prompt_tokens': 11, 'total_tokens': 273, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 192, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DeFXQJDbwZ4PHjOkbRbYk2jKWJSGt', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e15fa-c21e-72e1-96cb-2e6cb474fc81-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 11, 'output_tokens': 262, 'total_tokens': 27
# ...
