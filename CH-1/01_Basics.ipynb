# %% [markdown]
# # **LLM Call**

# %%
import os
from openai import OpenAI

client = OpenAI(api_key=os.environ.get("OPENAI_API_KEY"),
            project="proj_MupWofSsIPSb05HNiqXrgXjK"
            )
chat_completion = client.chat.completions.create(
    messages = [
        {
            "role":"user",
            "content":"Bro, tell me a fun fact about Iron Man!!"
        }
    ],
    model="gpt-5-mini",
)

print(chat_completion.choices[0].message.content)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[14], line 7
#       3
#       4 client = OpenAI(api_key=os.environ.get("OPENAI_API_KEY"),
#       5             project="proj_MupWofSsIPSb05HNiqXrgXjK"
#       6             )
# ----> 7 chat_completion = client.chat.completions.create(
#       8     messages = [
#       9         {
#      10             "role":"user",
#
# File c:\Users\yashk\OneDrive\Langchain_Tutorial\.venv\Lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File c:\Users\yashk\OneDrive\Langchain_Tutorial\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:1212, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1165 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1166 def create(
#    1167     self,
#    (...)   1209     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1210 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1211     validate_response_format(response_format)
# -> 1212     return self._post(
#    1213         "/chat/completions",
#    1214         body=maybe_transform(
#    1215             {
#    1216                 "messages": messages,
#    1217                 "model": model,
#    1218                 "audio": audio,
#    1219                 "frequency_penalty": frequency_penalty,
#    1220                 "function_call": function_call,
#    1221                 "functions": functions,
#    1222                 "logit_bias": logit_bias,
#    1223                 "logprobs": logprobs,
#    1224                 "max_completion_tokens": max_completion_tokens,
#    1225                 "max_tokens": max_tokens,
#    1226                 "metadata": metadata,
#    1227                 "modalities": modalities,
#    1228                 "n": n,
#    1229                 "parallel_tool_calls": parallel_tool_calls,
#    1230                 "prediction": prediction,
#    1231                 "presence_penalty": presence_penalty,
#    1232                 "prompt_cache_key": prompt_cache_key,
#    1233                 "prompt_cache_retention": prompt_cache_retention,
#    1234                 "reasoning_effort": reasoning_effort,
#    1235                 "response_format": response_format,
#    1236                 "safety_identifier": safety_identifier,
#    1237                 "seed": seed,
#    1238                 "service_tier": service_tier,
#    1239                 "stop": stop,
#    1240                 "store": store,
#    1241                 "stream": stream,
#    1242                 "stream_options": stream_options,
#    1243                 "temperature": temperature,
#    1244                 "tool_choice": tool_choice,
#    1245                 "tools": tools,
#    1246                 "top_logprobs": top_logprobs,
#    1247                 "top_p": top_p,
#    1248                 "user": user,
#    1249                 "verbosity": verbosity,
#    1250                 "web_search_options": web_search_options,
#    1251             },
#    1252             completion_create_params.CompletionCreateParamsStreaming
#    1253             if stream
#    1254             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1255         ),
#    1256         options=make_request_options(
#    1257             extra_headers=extra_headers,
#    1258             extra_query=extra_query,
#    1259             extra_body=extra_body,
#    1260             timeout=timeout,
#    1261             security={"bearer_auth": True},
#    1262         ),
#    1263         cast_to=ChatCompletion,
#    1264         stream=stream or False,
#    1265         stream_cls=Stream[ChatCompletionChunk],
#    1266     )
#
# File c:\Users\yashk\OneDrive\Langchain_Tutorial\.venv\Lib\site-packages\openai\_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\yashk\OneDrive\Langchain_Tutorial\.venv\Lib\site-packages\openai\_base_client.py:1105, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1102             err.response.read()
#    1104         log.debug("Re-raising status error")
# -> 1105         raise self._make_status_error_from_response(err.response) from None
#    1107     break
#    1109 assert response is not None, "could not resolve response (should never happen)"
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Incorrect API key provided: sk-...n8kA. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'code': 'invalid_api_key', 'param': None}, 'status': 401}

# %%
from openai import OpenAI
import os
from dotenv import load_dotenv

load_dotenv()

client = OpenAI(api_key=os.environ["OPENAI_API_KEY"])
models = client.models.list()

for m in models.data:
    print(m.id)

# %%
print("Key loaded:", os.environ.get("OPENAI_API_KEY"))
# Out:
# Key loaded: sk-...n8kA
