# %% [markdown]
# # **LLM Call**

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv

load_dotenv(override=True)

client = OpenAI(api_key=os.environ.get("OPENAI_API_KEY"),
            project="proj_MupWofSsIPSb05HNiqXrgXjK"
            )
chat_completion = client.chat.completions.create(
    messages = [
        {
            "role":"user",
            "content":"Bro, tell me a fun fact about Iron Man!!"
        }
    ],
    model="gpt-4o-mini-2024-07-18",
)

print(chat_completion.choices[0].message.content)
# Out:
# Sure! A fun fact about Iron Man is that the character was created by writer Larry Lieber, designed by Don Heck, and given an iconic look by artist Jack Kirby. Iron Man first appeared in "Tales of Suspense" #39 in March 1963. Interestingly, the character’s secret identity, Tony Stark, was initially portrayed as a wealthy industrialist and arms manufacturer, which sparked debates about corporate ethics and responsibility long before those discussions became more prevalent in popular culture. The series evolved significantly, especially with the introduction of the character's struggles with alcoholism in the 1970s, making Iron Man one of Marvel's more complex heroes!

# %%
from openai import OpenAI
import os
from dotenv import load_dotenv

load_dotenv(override=True)

client = OpenAI(api_key=os.environ["OPENAI_API_KEY"])
models = client.models.list()

for m in models.data:
    print(m.id)

# %%
from dotenv import load_dotenv

load_dotenv(override=True)
print("Key loaded:", os.environ.get("OPENAI_API_KEY"))
# Out:
# Key loaded: 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

# %%
from langchain_openai import ChatOpenAI
from langchain_anthropic import ChatAnthropic

llm_openai = ChatOpenAI(model="gpt-4o-mini-2024-07-18", temperature=0.7)


llm_openai.invoke("Bro, tell me a fun fact").content
# Out:
# "Sure! Did you know that honey never spoils? Archaeologists have found pots of honey in ancient Egyptian tombs that are over 3,000 years old and still perfectly edible! Honey's low moisture content and acidic pH create a hostile environment for bacteria and microorganisms, allowing it to last indefinitely. Sweet, right?"
