# %%
import os
from dotenv import load_dotenv

load_dotenv()

if os.environ.get("GROQ_API_KEY"):
    print("Bro, you got the key. Now, worlds is yours")
else:
    print("debugg yrr")

print(os.environ.get("GROQ_API_KEY"))

# %% [markdown]
# ### **Chain with Custom Runnable**

# %%
#TASK -1 [Prompt]

from langchain_core.prompts import ChatPromptTemplate, PromptTemplate

prompt_template = ChatPromptTemplate.from_messages([
    ("system","You are a helpful assistant"),
    ("human","{input}")
])

# %%
#TASK-2 [LLM]

from langchain_core.output_parsers import StrOutputParser
from langchain_ollama import ChatOllama

llm_openai = ChatOllama(model="llama3:8b",temperature=0)

response = llm_openai.invoke("What is earth?? in one sentence")
print(response.content)

# %%
#TASK-3 [Str Parser]

str_parser = StrOutputParser()

# %%
#TASK-4 [Custom Runnable]
from langchain_core.runnables import RunnableLambda

def dictionary_maker(text:str)-> dict:

    return {"text":text}

dictionary_maker_runnable = RunnableLambda(dictionary_maker)

# %%
#TASK-5 [Template for Post]

prompt_post = ChatPromptTemplate.from_messages(
    messages=[
        ("system","You're a social media post generator."),
        ("human","Create a post for the following text for LinkedIn : {text}")
    ]
)

# %%
#TASK-6 [Generate the Post]

llm_openai = ChatOllama(model="llama3:8b",temperature=0)

# %%
#Task-7 [String Parser]

str_parser = StrOutputParser()

# %%
#CHAIN
#To create chain

chain = prompt_template | llm_openai | str_parser | dictionary_maker_runnable | prompt_post | llm_openai | str_parser

chain.invoke("Ambitious person from India, dreaming to work in Japan AI Industry!!")
